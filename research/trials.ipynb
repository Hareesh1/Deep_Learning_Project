# %%
# config box
d = {"key": "val1", "key1": "val2"}

# %%
d['key']
# Out:
# 'val1'

# %%
d['key1']
# Out:
# 'val2'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key": "val1", "key1": "val2"})

# %%
d2.key1
# Out:
# 'val2'

# %%
def get_product(x:int, y:int) -> int:

    return x * y

# %%
get_product(3, 4)
# Out:
# 12
